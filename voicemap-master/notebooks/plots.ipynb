# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
plt.rcParams["font.family"] = "Times New Roman"

# %%
n_spkr = [2,5,10,50,100,250]
acc_1 = np.array([0.9621, 0.88179,0.7877, 0.5294, 0.43869, 0.25708])
acc_1_std = np.array([0.0518,0.0604, 0.0537, 0.034, 0.0222,0])

acc_2 = np.array([0.9925, 0.96585,0.9376, 0.7972, 0.7067, 0.5087])
acc_2_std = np.array([0.02926,0.03884, 0.0411, 0.0244, 0.0230,0])

acc_3 = np.array([0.9998, 0.99579,0.99013, 0.9598, 0.9397, 0.867])
acc_3_std = np.array([0.0013,0.011, 0.0099, 0.0104, 0.0111,0])

# %%
plt.errorbar(n_spkr, acc_1, acc_1_std, fmt ='-o', uplims=True, lolims=True, label='1secs')
plt.errorbar(n_spkr, acc_2, acc_2_std, fmt ='-o', uplims=True, lolims=True, label='2secs')
plt.errorbar(n_spkr, acc_3, acc_3_std, fmt ='-o', uplims=True, lolims=True, label='3secs')
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.legend(loc='lower left')
plt.show
plt.savefig('../plots/plots_acc_errorplot.png', dpi=250)

# %%
plt.errorbar(n_spkr[:-1], acc_1[:-1], acc_1_std[:-1], fmt ='-o', uplims=True, lolims=True, label='1secs')
plt.errorbar(n_spkr[:-1], acc_2[:-1], acc_2_std[:-1], fmt ='-o', uplims=True, lolims=True, label='2secs')
plt.errorbar(n_spkr[:-1], acc_3[:-1], acc_3_std[:-1], fmt ='-o', uplims=True, lolims=True, label='3secs')
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.legend(loc='lower left')
plt.show
plt.savefig('../plots/plots_acc_100_err.png', dpi=250)

# %%
## With thresholding
# Thr = mean - 2*std
acc_thr2 = np.array([0.9231,0.8921,0.8766, 0.8012,0.7458, 0.8445])
acc_thr2_err = np.array([0.096,0.0775,0.0539, 0.0257,0.0173,0])

acc_thr2_kn = np.array([0.9370,0.9437,0.9359, 0.89594,0.8795, 0.8445])
acc_thr2_kn_err = np.array([0.0334,0.0220,0.0173, 0.0095,0.0071,0])

acc_thr2_ukn = np.array([0.9121,0.8384,0.8029, 0.7094,0.6017, 0])
acc_thr2_ukn_err = np.array([0.174,0.1465,0.1103, 0.046,0.036,0])


# Thr = mean - std

acc_thr1 = np.array([0.8928,0.8868,0.8801, 0.8274,0.7935, 0.7234])
acc_thr1_err = np.array([0.083,0.065,0.047, 0.018,0.013,0])

acc_thr1_kn = np.array([0.8681,0.8883,0.880, 0.8135,0.7746, 0.7234])
acc_thr1_kn_err = np.array([0.0567,0.0393,0.0214, 0.0012,0.008,0])

acc_thr1_ukn = np.array([0.9133,0.8838,0.8798, 0.8412,0.8123, 0.])
acc_thr1_ukn_err = np.array([0.179,0.131,0.0930, 0.031,0.0222,0])

# %%
plt.errorbar(n_spkr[:-1], acc_thr2[:-1], acc_thr2_err[:-1], fmt ='-o', uplims=True, lolims=True, label='total')
plt.errorbar(n_spkr[:-1], acc_thr2_kn[:-1], acc_thr2_kn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='known')
plt.errorbar(n_spkr[:-1], acc_thr2_ukn[:-1], acc_thr2_ukn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='unknown')
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.title('Using Thr2 accuracy of known, unknown and mixed speakers')
plt.show
# plt.savefig('../plots/plots_acc_errorplot.png', dpi=250)
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.errorbar(n_spkr[:-1], acc_thr1[:-1], acc_thr1_err[:-1], fmt ='-o', uplims=True, lolims=True, label='total')
plt.errorbar(n_spkr[:-1], acc_thr1_kn[:-1], acc_thr1_kn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='known')
plt.errorbar(n_spkr[:-1], acc_thr1_ukn[:-1], acc_thr1_ukn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='unknown')
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.title('Using Thr1 accuracy of known, unknown and mixed speakers')
plt.show
# plt.savefig('../plots/plots_acc_errorplot.png', dpi=250)
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig, axes = plt.subplots(1,1)
axes.errorbar(n_spkr[:-1], acc_thr2[:-1], acc_thr2_err[:-1], color = 'C0',fmt ='-o', uplims=True, lolims=True, label='total')
axes.errorbar(n_spkr[:-1], acc_thr2_kn[:-1], acc_thr2_kn_err[:-1], linestyle='--', color = 'C0', fmt ='-o', uplims=True, lolims=True, label='known')
axes.errorbar(n_spkr[:-1], acc_thr2_ukn[:-1], acc_thr2_ukn_err[:-1], linestyle=':', color = 'C0', fmt ='-o', uplims=True, lolims=True, label='unknown')


axes.errorbar(n_spkr[:-1], acc_thr1[:-1], acc_thr1_err[:-1], color = 'C1', fmt ='-o', uplims=True, lolims=True, label='total')
axes.errorbar(n_spkr[:-1], acc_thr1_kn[:-1], acc_thr1_kn_err[:-1], linestyle='--', color = 'C1',fmt ='-o', uplims=True, lolims=True, label='known')
axes.errorbar(n_spkr[:-1], acc_thr1_ukn[:-1], acc_thr1_ukn_err[:-1], linestyle=':', color = 'C1',fmt ='-o', uplims=True, lolims=True, label='unknown')
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.title('Accuracy of known, unknown and mixed speakers')

lines = axes.get_lines()
print(lines)
legend1 = plt.legend([lines[i] for i in [0,3,6]], ['total', 'known', 'unknown'], loc =3)
legend2 = plt.legend([lines[i] for i in [0,9]], ['thr2', 'thr1'], loc =8)

axes.add_artist(legend1)
axes.add_artist(legend2)
plt.show
plt.savefig('../plots/plots_acc_thr_all.png', dpi=250)
# Out:
# <a list of 18 Line2D objects>

# %%
fig, ax = plt.subplots(1,3, figsize =(20,4))


ax[1].errorbar(n_spkr[:-1], acc_thr2_kn[:-1], acc_thr2_kn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr2')
ax[1].errorbar(n_spkr[:-1], acc_thr1_kn[:-1], acc_thr1_kn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr1')
ax[1].set_xlabel('Number of speakers')
ax[1].set_ylabel('Accuracy(known speakers)')
ax[1].legend(loc='upper right')
ax[1].set_title('Accuracy of known speakers after thresholding')

ax[2].errorbar(n_spkr[:-1], acc_thr2_ukn[:-1], acc_thr2_ukn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr2')
ax[2].errorbar(n_spkr[:-1], acc_thr1_ukn[:-1], acc_thr1_ukn_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr1')
ax[2].set_xlabel('Number of speakers')
ax[2].set_ylabel('Accuracy(unknown speakers)')
ax[2].legend(loc='upper right')
ax[2].set_title('Accuracy of unknown speakers after thresholding')

ax[0].errorbar(n_spkr[:-1], acc_thr2[:-1], acc_thr2_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr2')
ax[0].errorbar(n_spkr[:-1], acc_thr1[:-1], acc_thr1_err[:-1], fmt ='-o', uplims=True, lolims=True, label='thr1')
ax[0].set_xlabel('Number of known speakers')
ax[0].set_ylabel('Accuracy(known and unknown speakers)')
ax[0].legend(loc='upper right')
ax[0].set_title('Accuracy with known and unknown speakers after thresholding')

plt.show
plt.savefig('../plots/plots_acc_kn_ukn_all.png', dpi=250)

# %%
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Threshold1

# %%
total_acc_list = np.load('./saved_data/acc_3sec_thr1_both.npz.npy')
two_acc_list = np.load('./saved_data/acc_3sec_thr1_two.npz.npy')
other_acc_list = np.load('./saved_data/acc_3sec_thr1_other.npz.npy')
import matplotlib.pyplot as plt
total_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_both.npz.npy')
two_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_two.npz.npy')
other_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_other.npz.npy')

# %%
box1 = plt.boxplot(np.transpose(total_acc_list), \
                  positions = (1,5,9,13, 17), \
                  widths =1,
                patch_artist =True,
                  #labels= speaker_range, 
                  showfliers=False)

for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='blue')

box2 = plt.boxplot(np.transpose(two_acc_list), \
                   positions =(2, 6,10,14, 18),\
                   #labels= speaker_range, 
                   patch_artist =True,
                   widths =1,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='green')
        
box3 = plt.boxplot(np.transpose(other_acc_list), \
                   positions =(3,7,11,15, 19),\
                   patch_artist =True,
                   widths = 1,
                   #labels= speaker_range, 
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box3[element], color='red')
ax = plt.axes()
ax.set_xticklabels([0,2,5,10,50,100])
ax.set_xticks([0,2, 6,10,14, 18])
plt.ylim((0,1))

for b1 in [box1, box2, box3]:
    for ele in b1['boxes']:
        ele.set_facecolor('pink')
        #ele.set(hatch = '/')

plt.legend([box1["boxes"][1], box2["boxes"][0], box3["boxes"][0]],['mixed', 'known', 'unknown'])
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of known, unknown and mixed using thr1')
plt.ylim([0.4,1])
#plt.savefig('../plots/plots_acc_thr1_box.png', dpi=250)
plt.show()
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Threshold 2

# %%
# total_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_both.npz.npy')
# two_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_two.npz.npy')
# other_acc_list_2 = np.load('./saved_data/acc_3sec_thr2_other.npz.npy')

box1 = plt.boxplot(np.transpose(total_acc_list_2), \
                  positions = (1,5,9,13, 17), \
                  widths =1,patch_artist =True,
                  #labels= speaker_range, 
                  showfliers=False)
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='blue')

box2 = plt.boxplot(np.transpose(two_acc_list_2), \
                   positions =(2, 6,10,14, 18),\
                   #labels= speaker_range, 
                   widths =1,patch_artist =True,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='green')
        
box3 = plt.boxplot(np.transpose(other_acc_list_2), \
                   positions =(3,7,11,15, 19),\
                   widths = 1,patch_artist =True,
                   #labels= speaker_range, 
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box3[element], color='red')
ax = plt.axes()
ax.set_xticklabels([0,2,5,10,50,100])
ax.set_xticks([0,2, 6,10,14, 18])
plt.ylim((0,1))

for b1 in [box1, box2, box3]:
    for ele in b1['boxes']:
        ele.set_facecolor('lightblue')
        
plt.legend([box1["boxes"][0], box2["boxes"][0], box3["boxes"][0]],['mixed', 'known', 'unknown'])
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of known, unknown and mixed using thr2')
# plt.show()
plt.savefig('../plots/plots_acc_thr2_box.png', dpi=250)
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Known spkr plots:

# %%
box1 = plt.boxplot(np.transpose(two_acc_list), \
                   positions =(1,4,7,10,13),\
                   #labels= speaker_range, 
                   widths =1,
                   patch_artist = True,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='green')

box2 = plt.boxplot(np.transpose(two_acc_list_2), \
           positions =(2, 5,8,11, 14),\
           #labels= speaker_range, 
           widths =1,
            patch_artist = True,
           showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='green')

colors = ['pink', 'lightblue']

bplot = [box1, box2]

[ele.set_facecolor('pink') for ele in box1['boxes']]
[ele.set_facecolor('lightblue') for ele in box2['boxes']]
# box2['boxes'].set_facecolor('lightblue')
ax.xaxis.grid(True)

ax = plt.axes()
ax.set_xticklabels([0, 2,5,10,50,100])
ax.set_xticks([0, 1.5,4.5,7.5,10.5,13.5])
#ax.xaxis.grid(True)
plt.ylim((0,1))

plt.legend([box1["boxes"][0], box2["boxes"][0]],['thr1', 'thr2'], loc = 3)
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of known speakers')
plt.ylim([0.4,1])
# plt.show()
plt.savefig('../plots/plots_acc_kno_box-2.png', dpi=250)
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
box1 = plt.boxplot(np.transpose(other_acc_list), \
                   positions =(1,4,7,10,13),\
                   #labels= speaker_range, 
                   widths =1,
                   patch_artist = True,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='red')

box2 = plt.boxplot(np.transpose(other_acc_list_2), \
           positions =(2, 5,8,11, 14),\
           #labels= speaker_range, 
           widths =1,
            patch_artist = True,
           showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='red')

colors = ['pink', 'lightblue']

bplot = [box1, box2]

[ele.set_facecolor('pink') for ele in box1['boxes']]
[ele.set_facecolor('lightblue') for ele in box2['boxes']]
# box2['boxes'].set_facecolor('lightblue')
ax.xaxis.grid(True)

ax = plt.axes()
ax.set_xticklabels([0, 2,5,10,50,100])
ax.set_xticks([0, 1.5,4.5,7.5,10.5,13.5])
#ax.xaxis.grid(True)
plt.ylim((0.4,1))

plt.legend([box1["boxes"][0], box2["boxes"][0]],['thr1', 'thr2'], loc=3)
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of unknown speakers')
# plt.show()


plt.savefig('../plots/plots_acc_ukn_box-2.png', dpi=250)
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
box1 = plt.boxplot(np.transpose(total_acc_list), \
                   positions =(1,4,7,10,13),\
                   #labels= speaker_range, 
                   widths =1,
                   patch_artist = True,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='blue')

box2 = plt.boxplot(np.transpose(total_acc_list_2), \
           positions =(2, 5,8,11, 14),\
           #labels= speaker_range, 
           widths =1,
            patch_artist = True,
           showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='blue')

colors = ['pink', 'lightblue']

bplot = [box1, box2]

[ele.set_facecolor('pink') for ele in box1['boxes']]
[ele.set_facecolor('lightblue') for ele in box2['boxes']]
# box2['boxes'].set_facecolor('lightblue')
ax.xaxis.grid(True)

ax = plt.axes()
ax.set_xticklabels([0, 2,5,10,50,100])
ax.set_xticks([0, 1.5,4.5,7.5,10.5,13.5])
#ax.xaxis.grid(True)
plt.ylim((0.4,1))

plt.legend([box1["boxes"][0], box2["boxes"][0]],['thr1', 'thr2'], loc = 3)
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of mixed speakers')
# plt.show()
plt.savefig('../plots/plots_acc_both_box-2.png', dpi=250)
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## All together

# %%
box1 = plt.boxplot(np.transpose(total_acc_list), \
                  positions = (1,5,9,13, 17), \
                  widths =1,
                patch_artist =True,
                  #labels= speaker_range, 
                  showfliers=False)

for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box1[element], color='blue')

box2 = plt.boxplot(np.transpose(two_acc_list), \
                   positions =(2, 6,10,14, 18),\
                   #labels= speaker_range, 
                   patch_artist =True,
                   widths =1,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box2[element], color='green')
        
box3 = plt.boxplot(np.transpose(other_acc_list), \
                   positions =(3,7,11,15, 19),\
                   patch_artist =True,
                   widths = 1,
                   #labels= speaker_range, 
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box3[element], color='red')
ax = plt.axes()
ax.set_xticklabels([0,2,5,10,50,100])
ax.set_xticks([0,2, 6,10,14, 18])
plt.ylim((0,1))

for b1 in [box1, box2, box3]:
    for ele in b1['boxes']:
        ele.set_facecolor('pink')
        #ele.set(hatch = '/')


box4 = plt.boxplot(np.transpose(total_acc_list_2), \
                  positions = (1,5,9,13, 17), \
                  widths =1,patch_artist =True,
                  #labels= speaker_range, 
                  showfliers=False)
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box4[element], color='blue')

box5 = plt.boxplot(np.transpose(two_acc_list_2), \
                   positions =(2, 6,10,14, 18),\
                   #labels= speaker_range, 
                   widths =1,patch_artist =True,
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box5[element], color='green')
        
box6 = plt.boxplot(np.transpose(other_acc_list_2), \
                   positions =(3,7,11,15, 19),\
                   widths = 1,patch_artist =True,
                   #labels= speaker_range, 
                   showfliers=False,
                  )
for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(box6[element], color='red')
ax = plt.axes()
ax.set_xticklabels([0,2,5,10,50,100])
ax.set_xticks([0,2, 6,10,14, 18])
plt.ylim((0,1))


for b1 in [box4, box5, box6]:
    for ele in b1['boxes']:
        ele.set_facecolor('lightblue')
        
plt.legend([box["boxes"][0], box2["boxes"][0], box3["boxes"][0]],['mixed', 'known', 'unknown'])
plt.xlabel('Number of known speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy of known, unknown and mixed using thr1')
plt.show()
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Input lengths

# %%
acc_1 = np.load('./saved_data/acc_1sec.npy')
acc_2 = np.load('./saved_data/acc_2sec.npy')
acc_3 = np.load('./saved_data/acc_3sec_r.npy')
acc_4 = np.load('./saved_data/acc_4sec_r.npy')
acc_5 = np.load('./saved_data/acc_5sec_r.npy')

# %%
print("Len\t \t 2 \t 5 \t 10 \t 50 \t 100")
print("1 sec\t acc:\t %s" %'\t'.join(map(str,np.round(np.mean(acc_1, axis =1),4))))
print(" \t std:\t %s" %'\t'.join(map(str,np.round(np.std(acc_1, axis =1),4))))
print("2 sec \t acc:\t %s" %'\t'.join(map(str,np.round(np.mean(acc_2, axis =1),4))))
print(" \t std:\t %s" %'\t'.join(map(str,np.round(np.std(acc_2, axis =1),4))))
print("3 sec \t acc:\t %s" %'\t'.join(map(str,np.round(np.mean(acc_3, axis =1),4))))
print(" \t std:\t %s" %'\t'.join(map(str,np.round(np.std(acc_3, axis =1),4))))
print("4 sec \t acc:\t %s" %'\t'.join(map(str,np.round(np.mean(acc_4, axis =1),4))))
print(" \t std:\t %s" %'\t'.join(map(str,np.round(np.std(acc_4, axis =1),4))))
print("5 sec \t acc:\t %s" %'\t'.join(map(str,np.round(np.mean(acc_5, axis =1),4))))
print(" \t std:\t %s" %'\t'.join(map(str,np.round(np.std(acc_5, axis =1),4))))
# Out:
# Len	 	 2 	 5 	 10 	 50 	 100
# 1 sec	 acc:	 0.9551	0.8743	0.7768	0.5021	0.3876
#  	 std:	 0.0742	0.0602	0.0601	0.0248	0.0136
# 2 sec 	 acc:	 0.9961	0.9662	0.9328	0.7662	0.6622
#  	 std:	 0.0109	0.0361	0.0391	0.0287	0.0165
# 3 sec 	 acc:	 0.9971	0.9907	0.9765	0.8933	0.8276
#  	 std:	 0.0116	0.0189	0.0222	0.0191	0.0162
# 4 sec 	 acc:	 0.9969	0.9854	0.964	0.8502	0.7604
#  	 std:	 0.022	0.022	0.0273	0.0242	0.0185
# 5 sec 	 acc:	 0.9978	0.9858	0.9772	0.8876	0.8212
#  	 std:	 0.0075	0.0241	0.019	0.0215	0.015

# %%
speaker_range = [2,5,10,50,100]
box1 = plt.boxplot(np.transpose(acc_1), \
                   positions =(1,7,14, 21, 28),\
                   widths = 1,patch_artist =True,
                   labels= speaker_range, 
                   showfliers=False,
                  )
box2 = plt.boxplot(np.transpose(acc_2), \
                   positions =(2,8,15, 22, 29),\
                   widths = 1,patch_artist =True,
                   labels= speaker_range, 
                   showfliers=False,
                  )
box3 = plt.boxplot(np.transpose(acc_3), \
                   positions =(3,9,16, 23, 30),\
                   widths = 1,patch_artist =True,
                   labels= speaker_range, 
                   showfliers=False,
                  )
box4 = plt.boxplot(np.transpose(acc_4), \
                   positions =(4,10,17, 24, 31),\
                   widths = 1,patch_artist =True,
                   labels= speaker_range, 
                   showfliers=False,
                  )
box5 = plt.boxplot(np.transpose(acc_3), \
                   positions =(5,11,18, 25, 32),\
                   widths = 1,patch_artist =True,
                   labels= speaker_range, 
                   showfliers=False,
                  )
bplots = [box1, box2, box3, box4, box5]
colors = ['lightcoral', 'lightblue', 'lightgreen', 'lightyellow', 'lightgray']
for b1,c1 in zip(bplots, colors):
    for ele in b1['boxes']:
        ele.set_facecolor(c1)
    
    for element in ['whiskers', 'fliers', 'means', 'medians', 'caps']:
        plt.setp(b1[element], color='black')

ax = plt.axes()
ax.set_xticklabels([0,2,5,10,50,100])
ax.set_xticks([0, 3,9,16, 23, 30])

plt.legend([box1["boxes"][0], box2["boxes"][0], box3["boxes"][0], box4["boxes"][0], box5["boxes"][0]],\
          ['1sec', '2sec', '3sec', '4sec', '5sec'])
plt.xlabel('Number of speakers')
plt.ylabel('Accuracy')
plt.title('Accuracy vs input length')
plt.savefig('../plots/plots_acc_len_box.png', dpi=250)
plt.show()
# Out:
# /Users/sanmathikamath/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import numpy as np
emb = np.load('saved_data/emb_3sec_r.npy')
val_emb = np.load('saved_data/val_emb_3sec_r.npy')

# %%
from sklearn import svm
## Train Classifier
X_tr = emb
y_tr = y_train
clf = svm.SVC(gamma = 'scale', probability=True)
clf.fit(X_tr, y_tr)
